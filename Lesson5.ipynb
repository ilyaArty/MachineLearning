# %%
from scipy import misc
import matplotlib.pyplot as plt
# %matplotlib inline
im_arr = misc.imread('111.png')
plt.imshow(im_arr)

# %%
from scipy import misc
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
im_arr = misc.imread('boy.png')
vert=im_arr.shape[0]
hor=im_arr.shape[1]
im_arr2 = np.zeros((vert,hor))
i=0
j=0

while i<vert:
    while j<hor:
        im_arr2[i,j]=im_arr[i,j,0]*0.299+im_arr[i,j,1]*0.587+im_arr[i,j,2]*0.144;
        j=j+1;
    j=0;
    i=i+1;
print(im_arr2)
plt.imshow(im_arr2, cmap='gray')
# Out:
# [[  75.034   67.824   62.674 ...,    0.       0.       0.   ]
#  [  71.944   65.764   62.674 ...,    0.       0.       0.   ]
#  [  66.196   63.106   63.106 ...,    0.       0.       0.   ]
#  ...,
#  [ 190.639  209.622  206.986 ...,  242.426  244.774  244.774]
#  [ 192.998  196.686  233.777 ...,  243.035  243.035  243.323]
#  [ 204.937  199.798  207.894 ...,  243.201  242.913  242.913]]
